# %%
import cupy as cp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cupy as cp
#
# ModuleNotFoundError: No module named 'cupy'

# %%
pip install cupy
# Out:
# ...
#
#   Using cached cupy-12.1.0.tar.gz (2.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached fastrlock-0.8.1-cp311-cp311-win_amd64.whl (28 kB)
# ...
#   Running setup.py clean for cupy
# Failed to build cupy
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [57 lines of output]
#   Clearing directory: C:\Users\Leobardo\AppData\Local\Temp\pip-install-utn6g579\cupy_b44eddd3494244d38c20d6980cd51b96\cupy\.data
#   Looking for NVTX: C:\Program Files\NVIDIA Corporation\Nsight Systems *\target-windows-x64\nvtx
#   Using NVTX at: C:\Program Files\NVIDIA Corporation\Nsight Systems 2023.1.2\target-windows-x64\nvtx
#
#   -------- Configuring Module: cuda --------
#   Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
# ...
